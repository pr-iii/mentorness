# %% [markdown]
# # Disease prediction

# %%
#importing Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix

# %%
#Reading the train_data.csv file
df =  pd.read_csv("train_data.csv")

# %%
# Display the first few rows
df.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Glucose                                    2351 non-null   float64
#  1   Cholesterol                                2351 non-null   float64
#  2   Hemoglobin                                 2351 non-null   float64
#  3   Platelets                                  2351 non-null   float64
#  4   White Blood Cells                          2351 non-null   float64
#  5   Red Blood Cells                            2351 non-null   float64
#  6   Hematocrit                                 2351 non-null   float64
#  7   Mean Corpuscular Volume                    2351 non-null   float64
#  8   Mean Corpuscular Hemoglobin                2351 non-null   float64
#  9   Mean Corpuscular Hemoglobin Concentration  2351 non-null   float64
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Glucose                                      0
# Cholesterol                                  0
# Hemoglobin                                   0
# Platelets                                    0
# White Blood Cells                            0
# Red Blood Cells                              0
# Hematocrit                                   0
# Mean Corpuscular Volume                      0
# Mean Corpuscular Hemoglobin                  0
# Mean Corpuscular Hemoglobin Concentration    0
# Insulin                                      0
# BMI                                          0
# Systolic Blood Pressure                      0
# Diastolic Blood Pressure                     0
# Triglycerides                                0
# HbA1c                                        0
# LDL Cholesterol                              0
# HDL Cholesterol                              0
# ALT                                          0
# AST                                          0
# ...

# %%
df.describe()
# Out:
#            Glucose  Cholesterol   Hemoglobin    Platelets  White Blood Cells  \
# count  2351.000000  2351.000000  2351.000000  2351.000000        2351.000000
# mean      0.362828     0.393648     0.586190     0.504027           0.511086
# std       0.251889     0.239449     0.271498     0.303347           0.277270
# min       0.010994     0.012139     0.003021     0.012594           0.010139
# 25%       0.129198     0.195818     0.346092     0.200865           0.259467
# 50%       0.351722     0.397083     0.609836     0.533962           0.527381
# 75%       0.582278     0.582178     0.791215     0.754841           0.743164
# max       0.968460     0.905026     0.983306     0.999393           0.990786
#
#        Red Blood Cells   Hematocrit  Mean Corpuscular Volume  \
# count      2351.000000  2351.000000              2351.000000
# mean          0.506590     0.507152                 0.492200
# std           0.266565     0.285537                 0.275735
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df.drop('Disease', axis=1))

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Disease', axis=1), df['Disease'], test_size=0.3, random_state=10)

# %%
#train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#evaluate the model
pred = model.predict(X_test)
pred
# Out:
# array(['Anemia', 'Thalasse', 'Diabetes', 'Thalasse', 'Anemia', 'Thalasse',
#        'Anemia', 'Thalasse', 'Thalasse', 'Anemia', 'Anemia', 'Thromboc',
#        'Thalasse', 'Thalasse', 'Diabetes', 'Healthy', 'Diabetes',
#        'Thromboc', 'Anemia', 'Thalasse', 'Thalasse', 'Diabetes',
#        'Diabetes', 'Thalasse', 'Thalasse', 'Thromboc', 'Thalasse',
#        'Healthy', 'Anemia', 'Thromboc', 'Thromboc', 'Anemia', 'Diabetes',
#        'Anemia', 'Anemia', 'Diabetes', 'Healthy', 'Anemia', 'Anemia',
#        'Diabetes', 'Anemia', 'Diabetes', 'Healthy', 'Thalasse',
#        'Thalasse', 'Anemia', 'Anemia', 'Diabetes', 'Healthy', 'Thalasse',
#        'Thalasse', 'Healthy', 'Diabetes', 'Healthy', 'Thalasse',
#        'Healthy', 'Anemia', 'Thalasse', 'Anemia', 'Diabetes', 'Anemia',
#        'Anemia', 'Anemia', 'Thromboc', 'Healthy', 'Anemia', 'Thalasse',
#        'Thalasse', 'Healthy', 'Thalasse', 'Diabetes', 'Anemia', 'Healthy',
# ...

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[181,   0,   0,   0,   0],
#        [  0, 157,   0,   0,   0],
#        [  0,   0, 166,   0,   0],
#        [  0,   0,   0, 157,   0],
#        [  0,   0,   0,   0,  45]], dtype=int64)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       Anemia       1.00      1.00      1.00       181
#     Diabetes       1.00      1.00      1.00       157
#      Healthy       1.00      1.00      1.00       166
#     Thalasse       1.00      1.00      1.00       157
#     Thromboc       1.00      1.00      1.00        45
#
#     accuracy                           1.00       706
#    macro avg       1.00      1.00      1.00       706
# weighted avg       1.00      1.00      1.00       706

# %%
accuracy_score(y_test, pred)
# Out:
# 1.0

# %%
X_train = pd.read_csv('Train_data.csv')
X_test = pd.read_csv('test_data.csv')
X_test = X_test.drop('Disease', axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.drop('Disease', axis=1))
X_test_scaled = scaler.transform(X_test)
y_train = X_train['Disease']

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
prediction = model.predict(X_test_scaled)
prediction
# Out:
# array(['Diabetes', 'Diabetes', 'Healthy', 'Anemia', 'Healthy', 'Healthy',
#        'Diabetes', 'Healthy', 'Diabetes', 'Diabetes', 'Anemia',
#        'Diabetes', 'Healthy', 'Diabetes', 'Thalasse', 'Diabetes',
#        'Healthy', 'Anemia', 'Anemia', 'Anemia', 'Healthy', 'Thalasse',
#        'Diabetes', 'Diabetes', 'Diabetes', 'Diabetes', 'Anemia',
#        'Diabetes', 'Healthy', 'Healthy', 'Diabetes', 'Diabetes', 'Anemia',
#        'Diabetes', 'Diabetes', 'Diabetes', 'Anemia', 'Thalasse',
#        'Healthy', 'Thalasse', 'Anemia', 'Diabetes', 'Thalasse',
#        'Diabetes', 'Diabetes', 'Anemia', 'Healthy', 'Anemia', 'Anemia',
#        'Diabetes', 'Anemia', 'Anemia', 'Diabetes', 'Diabetes', 'Anemia',
#        'Thalasse', 'Thalasse', 'Anemia', 'Diabetes', 'Diabetes', 'Anemia',
#        'Diabetes', 'Diabetes', 'Healthy', 'Anemia', 'Anemia', 'Diabetes',
#        'Diabetes', 'Diabetes', 'Anemia', 'Healthy', 'Diabetes', 'Anemia',
# ...
